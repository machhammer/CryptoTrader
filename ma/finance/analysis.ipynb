# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import data_provider.DataReader as data_provider
import config as cfg
import yahoo_fin.stock_info as yf
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\tech_projects\CryptoTrader\ma\finance\analysis.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/d%3A/tech_projects/CryptoTrader/ma/finance/analysis.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import datetime as dt
#       <a href='vscode-notebook-cell:/d%3A/tech_projects/CryptoTrader/ma/finance/analysis.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from dateutil.relativedelta import relativedelta
# ----> <a href='vscode-notebook-cell:/d%3A/tech_projects/CryptoTrader/ma/finance/analysis.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import data_provider.DataReader as data_provider
#       <a href='vscode-notebook-cell:/d%3A/tech_projects/CryptoTrader/ma/finance/analysis.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import config as cfg
#       <a href='vscode-notebook-cell:/d%3A/tech_projects/CryptoTrader/ma/finance/analysis.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import yahoo_fin.stock_info as yf
#
# File d:\tech_projects\CryptoTrader\ma\finance\data_provider\DataReader.py:2
#       1 import requests
# ----> 2 import pandas_datareader as web
#       3 import pandas as pd
#       4 import config as cfg
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
end_date = dt.datetime.now()
start_date = end_date - relativedelta(months=6)

yf.get_data("xrp-usd", start_date = start_date, end_date = end_date, index_as_date = True, interval = '1d')
