# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import data_provider.DataReader as data_provider
import config as cfg
import yahoo_fin.stock_info as yf
import pandas as pd

# %%
end_date = dt.datetime.now()
start_date = end_date - relativedelta(months=6)

yf.get_data("xrp-usd", start_date = start_date, end_date = end_date, index_as_date = True, interval = '1d')
# Out:
#                 open      high       low     close  adjclose      volume  \
# 2023-04-28  0.466885  0.481096  0.464622  0.480271  0.480271  1145414603
# 2023-04-29  0.480237  0.485061  0.475726  0.478409  0.478409   611537970
# 2023-04-30  0.478377  0.481816  0.470954  0.472332  0.472332   556459700
# 2023-05-01  0.472205  0.472579  0.457182  0.464966  0.464966   941003865
# 2023-05-02  0.464976  0.465829  0.459436  0.464951  0.464951   903846077
# ...              ...       ...       ...       ...       ...         ...
# 2023-10-24  0.546893  0.582973  0.537455  0.558532  0.558532  2705905445
# 2023-10-25  0.558620  0.562377  0.542238  0.555306  0.555306  1396455738
# 2023-10-26  0.555353  0.566775  0.544552  0.553683  0.553683  1401251370
# 2023-10-27  0.553685  0.557566  0.539478  0.546107  0.546107  1048891335
# 2023-10-28  0.545715  0.546623  0.541652  0.546623  0.546623   855516864
#
#              ticker
# 2023-04-28  XRP-USD
# 2023-04-29  XRP-USD
# 2023-04-30  XRP-USD
# 2023-05-01  XRP-USD
# 2023-05-02  XRP-USD
# ...             ...
# 2023-10-24  XRP-USD
# 2023-10-25  XRP-USD
# 2023-10-26  XRP-USD
# 2023-10-27  XRP-USD
# 2023-10-28  XRP-USD
#
# [184 rows x 7 columns]
