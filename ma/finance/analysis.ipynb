# %%
import datetime as dt
from dateutil.relativedelta import relativedelta
import data_provider.DataReader as data_provider
from trading import SMAStrategy
import config as cfg
import yahoo_fin.stock_info as yf
import pandas as pd
import backtrader as bt

# %%
end_date = dt.datetime.now()
start_date = end_date - relativedelta(months=6)

data = yf.get_data("xrp-usd", start_date = start_date, end_date = end_date, index_as_date = True, interval = '1d')

# %%
cerebro = bt.Cerebro()
cerebro.adddata(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4772\1259398444.py in ?()
#       1 cerebro = bt.Cerebro()
# ----> 2 cerebro.adddata(data)
#
# c:\Users\Marku\.conda\envs\finance2\Lib\site-packages\backtrader\cerebro.py in ?(self, data, name)
#     759         if name is not None:
#     760             data._name = name
#     761
#     762         data._id = next(self._dataid)
# --> 763         data.setenvironment(self)
#     764
#     765         self.datas.append(data)
#     766         self.datasbyname[data._name] = data
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'setenvironment'
